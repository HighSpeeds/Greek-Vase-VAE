# %%
from keras.datasets import mnist
from tsnecuda import TSNE
# import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(y_train.shape)
print(x_train.shape)

tsne = TSNE(n_iter=1000, verbose=1, num_neighbors=64)
tsne_results = tsne.fit_transform(x_train.reshape(60000,-1))


print(tsne_results.shape)

# Create the figure
# fig = plt.figure( figsize=(8,8) )
# ax = fig.add_subplot(1, 1, 1, title='TSNE' )

# # Create the scatter
# ax.scatter(
#     x=tsne_results[:,0],
#     y=tsne_results[:,1],
#     c=y_train,
#     cmap=plt.cm.get_cmap('Paired'),
#     alpha=0.4,
#     s=0.5)
# plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# (60000,)
# (60000, 28, 28)
# Initializing cuda handles... done.
# KNN Computation... done.
# Computing Pij matrix...
# done.
# Initializing low dim points... done.
# Initializing CUDA memory... done.
# [Step 0] Avg. Gradient Norm: 0.00112683
# [Step 10] Avg. Gradient Norm: 0.00206777
# [Step 20] Avg. Gradient Norm: 0.00037581
# [Step 30] Avg. Gradient Norm: 8.44139e-05
# [Step 40] Avg. Gradient Norm: 5.76589e-05
# [Step 50] Avg. Gradient Norm: 8.1877e-05
# [Step 60] Avg. Gradient Norm: 0.000150402
# [Step 70] Avg. Gradient Norm: 0.00030572
# [Step 80] Avg. Gradient Norm: 0.000673089
# [Step 90] Avg. Gradient Norm: 0.00160844
# [Step 100] Avg. Gradient Norm: 0.004188
# [Step 110] Avg. Gradient Norm: 0.0119147
# [Step 120] Avg. Gradient Norm: 0.0370894
# [Step 130] Avg. Gradient Norm: 0.126358
# [Step 140] Avg. Gradient Norm: 0.470371
# [Step 150] Avg. Gradient Norm: 1.87896
# [Step 160] Avg. Gradient Norm: 6.45161
# [Step 170] Avg. Gradient Norm: 9.61348
# [Step 180] Avg. Gradient Norm: 8.5772
# [Step 190] Avg. Gradient Norm: 7.31117
# [Step 200] Avg. Gradient Norm: 6.51489
# [Step 210] Avg. Gradient Norm: 6.12061
# [Step 220] Avg. Gradient Norm: 5.7858
# [Step 230] Avg. Gradient Norm: 5.4446
# [Step 240] Avg. Gradient Norm: 5.2426
# [Step 250] Avg. Gradient Norm: 7.74442
# [Step 260] Avg. Gradient Norm: 19.0495
# [Step 270] Avg. Gradient Norm: 16.9164
# [Step 280] Avg. Gradient Norm: 14.4597
# [Step 290] Avg. Gradient Norm: 12.881
# [Step 300] Avg. Gradient Norm: 11.8818
# [Step 310] Avg. Gradient Norm: 11.2021
# [Step 320] Avg. Gradient Norm: 10.6753
# [Step 330] Avg. Gradient Norm: 10.2369
# [Step 340] Avg. Gradient Norm: 9.87569
# [Step 350] Avg. Gradient Norm: 9.57714
# [Step 360] Avg. Gradient Norm: 9.3201
# [Step 370] Avg. Gradient Norm: 9.09689
# [Step 380] Avg. Gradient Norm: 8.90763
# [Step 390] Avg. Gradient Norm: 8.74543
# [Step 400] Avg. Gradient Norm: 8.60403
# [Step 410] Avg. Gradient Norm: 8.48488
# [Step 420] Avg. Gradient Norm: 8.38037
# [Step 430] Avg. Gradient Norm: 8.28209
# [Step 440] Avg. Gradient Norm: 8.19183
# [Step 450] Avg. Gradient Norm: 8.10376
# [Step 460] Avg. Gradient Norm: 8.02477
# [Step 470] Avg. Gradient Norm: 7.95739
# [Step 480] Avg. Gradient Norm: 7.90045
# [Step 490] Avg. Gradient Norm: 7.8487
# [Step 500] Avg. Gradient Norm: 7.80285
# [Step 510] Avg. Gradient Norm: 7.76181
# [Step 520] Avg. Gradient Norm: 7.72487
# [Step 530] Avg. Gradient Norm: 7.691
# [Step 540] Avg. Gradient Norm: 7.65992
# [Step 550] Avg. Gradient Norm: 7.63178
# [Step 560] Avg. Gradient Norm: 7.60657
# [Step 570] Avg. Gradient Norm: 7.58491
# [Step 580] Avg. Gradient Norm: 7.56605
# [Step 590] Avg. Gradient Norm: 7.55046
# [Step 600] Avg. Gradient Norm: 7.53853
# [Step 610] Avg. Gradient Norm: 7.5297
# [Step 620] Avg. Gradient Norm: 7.52391
# [Step 630] Avg. Gradient Norm: 7.52054
# [Step 640] Avg. Gradient Norm: 7.51764
# [Step 650] Avg. Gradient Norm: 7.51493
# [Step 660] Avg. Gradient Norm: 7.5121
# [Step 670] Avg. Gradient Norm: 7.50906
# [Step 680] Avg. Gradient Norm: 7.50337
# [Step 690] Avg. Gradient Norm: 7.49494
# [Step 700] Avg. Gradient Norm: 7.48364
# [Step 710] Avg. Gradient Norm: 7.47201
# [Step 720] Avg. Gradient Norm: 7.46559
# [Step 730] Avg. Gradient Norm: 7.46362
# [Step 740] Avg. Gradient Norm: 7.46491
# [Step 750] Avg. Gradient Norm: 7.46812
# [Step 760] Avg. Gradient Norm: 7.47172
# [Step 770] Avg. Gradient Norm: 7.47552
# [Step 780] Avg. Gradient Norm: 7.48035
# [Step 790] Avg. Gradient Norm: 7.48589
# [Step 800] Avg. Gradient Norm: 7.49159
# [Step 810] Avg. Gradient Norm: 7.49809
# [Step 820] Avg. Gradient Norm: 7.50563
# [Step 830] Avg. Gradient Norm: 7.51423
# [Step 840] Avg. Gradient Norm: 7.52298
# [Step 850] Avg. Gradient Norm: 7.53273
# [Step 860] Avg. Gradient Norm: 7.55257
# [Step 870] Avg. Gradient Norm: 7.57037
# [Step 880] Avg. Gradient Norm: 7.57011
# [Step 890] Avg. Gradient Norm: 7.57164
# [Step 900] Avg. Gradient Norm: 7.57815
# [Step 910] Avg. Gradient Norm: 7.58727
# [Step 920] Avg. Gradient Norm: 7.59977
# [Step 930] Avg. Gradient Norm: 7.614
# [Step 940] Avg. Gradient Norm: 7.63066
# [Step 950] Avg. Gradient Norm: 7.6504
# [Step 960] Avg. Gradient Norm: 7.67271
# [Step 970] Avg. Gradient Norm: 7.68668
# [Step 980] Avg. Gradient Norm: 7.69861
# [Step 990] Avg. Gradient Norm: 7.70768
# _time_initialization: 1.46111s
# _time_knn: 2.20782s
# _time_symmetry: 0.011351s
# _time_init_low_dim: 0.002567s
# _time_init_fft: 0.109644s
# _time_compute_charges: 0.001076s
# _time_precompute_2d: 0.249796s
# _time_nbodyfft: 0.951105s
# _time_norm: 0.027923s
# _time_attr: 0.383507s
# _time_apply_forces: 0.082167s
# _time_other: 0.01975s
# total_time: 5.50781s
# (60000, 2)
